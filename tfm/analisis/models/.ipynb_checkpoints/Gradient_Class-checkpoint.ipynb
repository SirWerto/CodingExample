# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, plot_roc_curve, plot_confusion_matrix

# %%
data = pd.read_csv("/home/jorge/tfm-jvm/data/data/data_7.csv")
target_classic = pd.read_csv("/home/jorge/tfm-jvm/data/data/target_classic.csv")
X = data.merge(target_classic, on="id_p")
X.head()
# Out:
#           id_p  n_days  N_last  N_first  N_diff_positive  N_diff_negative  \
# 0            9       7       3        2              1.0              0.0
# 1           10       7      17       16              1.0              0.0
# 2           12       7       3        3              0.0              0.0
# 3           14       7       2        2              0.0              0.0
# 4           19       7       1        1              0.0              0.0
# ...        ...     ...     ...      ...              ...              ...
# 117746  325241       7       1        1              0.0              0.0
# 117747  325245       7       2        1              1.0              0.0
# 117748  325246       7       1        1              0.0              0.0
# 117749  325248       7       2        2              0.0              0.0
# 117750  325249       7       7        5              3.0             -1.0
#
#         pop_sum_mean  pop_sum_std  pop_mean_mean  pop_mean_std  ...  \
# 0        1013.714286   257.146336     370.380952     45.911621  ...
# 1       12741.428571   418.476944     762.258403      6.744138  ...
# 2        1611.857143   111.475601     537.285714     37.158534  ...
# 3         369.428571     5.563486     184.714286      2.781743  ...
# 4         214.285714    22.932613     214.285714     22.932613  ...
# ...              ...          ...            ...           ...  ...
# 117746    372.285714   132.022365     372.285714    132.022365  ...
# 117747    474.571429   114.277232     283.285714     36.341961  ...
# 117748    205.142857    27.051978     205.142857     27.051978  ...
# 117749    322.142857    34.681544     161.071429     17.340772  ...
# 117750   2727.571429   182.776601     481.306122     40.367787  ...
#
#         romanos_increase  germanos_increase  galos_increase  \
# 0                      0                  0               1
# 1                      1                  0               0
# 2                      0                  0               0
# 3                      0                  0               0
# 4                      0                  0               0
# ...                  ...                ...             ...
# 117746                 0                  0               0
# 117747                 0                  0               1
# 117748                 0                  0               0
# 117749                 0                  0               0
# 117750                 0                  0               2
#
#         egipcios_increase  hunos_increase  rs_day_last    p_play  \
# 0                       0               0           16  0.857143
# 1                       0               0          137  1.000000
# 2                       0               0           16  1.000000
# 3                       0               0           13  0.428571
# 4                       0               0           30  0.714286
# ...                   ...             ...          ...       ...
# 117746                  0               0           16  0.571429
# 117747                  0               0           30  0.857143
# 117748                  0               0           35  1.000000
# 117749                  0               0           32  0.714286
# 117750                  0               0           23  0.285714
#
#         p_play_weekend  p_play_week  inactive
# 0                  0.5          1.0     False
# 1                  1.0          1.0     False
# 2                  1.0          1.0      True
# 3                  0.5          0.4      True
# 4                  0.5          0.8     False
# ...                ...          ...       ...
# 117746             0.5          0.6      True
# 117747             1.0          0.8     False
# 117748             1.0          1.0     False
# 117749             0.0          1.0     False
# 117750             0.5          0.2     False
#
# [117751 rows x 31 columns]

# %% [markdown]
# ## Split

# %%
del X["id_p"], X["n_days"]
y = X["inactive"]
del X["inactive"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %% [markdown]
# # Gradient

# %%
clf = GradientBoostingClassifier(loss="deviance", learning_rate=0.14, n_estimators=500)

# %%
# %%time
clf.fit(X_train, y_train)
# Out:
# CPU times: user 1min 39s, sys: 26.8 ms, total: 1min 39s
# Wall time: 1min 40s
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.14, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=500,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9762042258305591

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Results

# %%
plot_confusion_matrix(clf, X_test, y_test, normalize="true")
