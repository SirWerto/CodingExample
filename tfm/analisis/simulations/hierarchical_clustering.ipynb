# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("/home/jorge/tfm-jvm/data/data/data_7.csv")
data
# Out:
#         n_days  N_last  N_first  N_diff_positive  N_diff_negative  \
# 0            7       3        2              1.0              0.0
# 1            7      17       16              1.0              0.0
# 2            7       3        3              0.0              0.0
# 3            7       2        2              0.0              0.0
# 4            7       1        1              0.0              0.0
# ...        ...     ...      ...              ...              ...
# 117747       7       1        1              0.0              0.0
# 117748       7       2        1              1.0              0.0
# 117749       7       1        1              0.0              0.0
# 117750       7       2        2              0.0              0.0
# 117751       7       7        5              3.0             -1.0
#
#         pop_sum_mean  pop_sum_std  pop_mean_mean  pop_mean_std  \
# 0        1013.714286   257.146336     370.380952     45.911621
# 1       12741.428571   418.476944     762.258403      6.744138
# 2        1611.857143   111.475601     537.285714     37.158534
# 3         369.428571     5.563486     184.714286      2.781743
# 4         214.285714    22.932613     214.285714     22.932613
# ...              ...          ...            ...           ...
# 117747    372.285714   132.022365     372.285714    132.022365
# 117748    474.571429   114.277232     283.285714     36.341961
# 117749    205.142857    27.051978     205.142857     27.051978
# 117750    322.142857    34.681544     161.071429     17.340772
# 117751   2727.571429   182.776601     481.306122     40.367787
#
#         norm2_mean_mean  ...  hunos  romanos_increase  germanos_increase  \
# 0             47.580120  ...      0                 0                  0
# 1             62.318751  ...      0                 1                  0
# 2            191.223381  ...      3                 0                  0
# 3            117.222537  ...      0                 0                  0
# 4             94.831429  ...      0                 0                  0
# ...                 ...  ...    ...               ...                ...
# 117747       149.187801  ...      0                 0                  0
# 117748       110.448218  ...      0                 0                  0
# 117749       100.801786  ...      0                 0                  0
# 117750       113.135773  ...      0                 0                  0
# 117751       133.324710  ...      0                 0                  0
#
#         galos_increase  egipcios_increase  hunos_increase  rs_day_last  \
# 0                    1                  0               0           16
# 1                    0                  0               0          137
# 2                    0                  0               0           16
# 3                    0                  0               0           13
# 4                    0                  0               0           30
# ...                ...                ...             ...          ...
# 117747               0                  0               0           16
# 117748               1                  0               0           30
# 117749               0                  0               0           35
# 117750               0                  0               0           32
# 117751               2                  0               0           23
#
#           p_play  p_play_weekend  p_play_week
# 0       0.857143             0.5          1.0
# 1       1.000000             1.0          1.0
# 2       1.000000             1.0          1.0
# 3       0.428571             0.5          0.4
# 4       0.714286             0.5          0.8
# ...          ...             ...          ...
# 117747  0.571429             0.5          0.6
# 117748  0.857143             1.0          0.8
# 117749  1.000000             1.0          1.0
# 117750  0.714286             0.0          1.0
# 117751  0.285714             0.5          0.2
#
# [117752 rows x 33 columns]

# %% [markdown]
# ## Cluster

# %%
# %%time
Z = hierarchy.linkage(data, method='single', metric='euclidean', optimal_ordering=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/envs/tfm_jvm/lib/python3.7/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1054                          'matrix looks suspiciously like an uncondensed '
#    1055                          'distance matrix')
# -> 1056         y = distance.pdist(y, metric)
#    1057     else:
#    1058         raise ValueError("`y` must be 1 or 2 dimensional.")
#
# ~/miniconda3/envs/tfm_jvm/lib/python3.7/site-packages/scipy/spatial/distance.py in pdist(X, metric, *args, **kwargs)
#    2002     out = kwargs.pop("out", None)
#    2003     if out is None:
# -> 2004         dm = np.empty((m * (m - 1)) // 2, dtype=np.double)
#    2005     else:
#    2006         if out.shape != (m * (m - 1) // 2,):
#
# MemoryError: Unable to allocate 51.7 GiB for an array with shape (6932707876,) and data type float64

# %%
#Save clustering

# %% [markdown]
# ### Plot

# %%
dn = hierarchy.dendrogram(Z)
